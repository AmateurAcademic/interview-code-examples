# %%
import pandas as pd
import numpy as np

from gensim.models import Word2Vec

from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier

from sklearn.metrics import f1_score
from sklearn.model_selection import learning_curve,validation_curve
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
def load_data(file_name):
    return pd.read_csv(file_name, sep=';')

# %%
# For this example, we will keep tokenization easy
def preprocess_lower(token):
    #utility for preprocessing
    return token.lower()

# %%
def process_training_data(training_data):
    # process the training data and split it between independent and dependent variables
    training_sentences = [list(map(preprocess_lower,sentence.split(" "))) for sentence in list(training_data.Utterence.values)]
    target_class = training_data.Intent.values
    label_encoded_Y = preprocessing.LabelEncoder().fit_transform(list(target_class))
    return target_class, training_sentences, label_encoded_Y

# %%
def process_user_query(training_data):
    # process the training data and split it between independent and dependent variables
    training_sentences = [list(map(preprocess_lower,sentence.split(" "))) for sentence in training_data]
    return training_sentences

# %%
def train_word2vec_model(train_sentences_list):
    # training word2vec on sentences list (inputted by user)
    model = Word2Vec(train_sentences_list, vector_size=100, window=4, min_count=1, workers=4)
    return model

# %%
def convert_training_data_vectors(model, train_sentences_list):
    #get the sentences average vector
    training_sectences_vector = list()
    for sentence in train_sentences_list:
        sentence_vetor = [list(model.wv[token]) for token in sentence if token in model.wv.key_to_index.keys()]
        training_sectences_vector.append(list(np.mean(sentence_vetor, axis=0)))
    return training_sectences_vector

# %%
# This code needs to be used with training_rf_prediction_model to make a funtion that trains several models
# TODO: Use the multi-training model function instead of a function for each:

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, train_size=0.80, random_state=42)

# Show the results of the split
print("Training set has {} samples.".format(X_train.shape[0]))
print("Testing set has {} samples.".format(X_test.shape[0]))

objects = ('Multi-NB','DTs', 'AdaBoost', 'KNN', 'RF', 'SVM')


# function to train classifier
def train_classifier(clf, X_train, y_train):    
    clf.fit(X_train, y_train)

# function to predict features 
def predict_labels(clf, features):
    return(clf.predict(features))

A = MultinomialNB(alpha=1.0,fit_prior=True)
B = DecisionTreeClassifier(random_state=42)
C = AdaBoostClassifier(n_estimators=100) 
D = KNeighborsClassifier(n_neighbors=1)
E = RandomForestClassifier(n_estimators=10, max_depth=None, min_samples_split=2, random_state=0)
F = svm.SVC(kernel='linear', C=1)


# Loop to call function for each model
# Add compare of best model to export selection in the future
clf = [A,B,C,D,E,F]
cf_labels = ['NB', 'DT', 'ADA', 'KN', 'RF', 'SVM']
pred_val = [0,0,0,0,0,0]

for a in range(0,6):
    train_classifier(clf[a], X_train, y_train)
    y_pred = predict_labels(clf[a],X_test)
    pred_val[a] = f1_score(y_test, y_pred) 
    print(pred_val[a])
    cf_name = cf_labels[a]

# %%
def training_rf_prediction_model(training_data_vectors, label_encoded_Y):
    # training model on user inputted data 
    random_forest_model = RandomForestClassifier()
    # here use the split function and divide the data into training and testing 
    x_train,x_test,y_train,y_test=train_test_split(training_data_vectors,label_encoded_Y,
    train_size=0.8,test_size=0.2)
    random_forest_model.fit(x_train, y_train)
    y_pred = random_forest_model.predict(x_test)
    print(accuracy_score(y_test, y_pred))
    return random_forest_model

# %%
def training_svm_prediction_model(training_data_vectors, label_encoded_Y):
    svm_model = svm.SVC(gamma='auto')
    svm_model.fit(training_data_vectors, label_encoded_Y)
    return svm_model

# %%
def process_data_flow(file_name):
    training_data = load_data(file_name)
    training_data.dropna(axis=0, how='any', subset=['answer_normalised'], inplace=True)
    target_class, training_sentences, label_encoded_Y = process_training_data(training_data)
    word2vec_model = train_word2vec_model(train_sentences_list=training_sentences)
    training_data_vectors = convert_training_data_vectors(word2vec_model, train_sentences_list=training_sentences)
    prediction_model = training_rf_prediction_model(training_data_vectors, label_encoded_Y)
    #intent prediction on user query
    userQuery = ["turn off the lights"]
    user_query_vectors = convert_training_data_vectors(word2vec_model, process_user_query(userQuery))
    predicted_class = prediction_model.predict(user_query_vectors)[0]
    predicted_intent = target_class[list(label_encoded_Y).index(predicted_class)]
    return predicted_intent

# %%
# Seperated training stuff to get model
training_data = load_data('NLU-Data-Home-Domain-Annotated-All.csv')
training_data.dropna(axis=0, how='any', subset=['answer_normalised'], inplace=True)
target_class, training_sentences, label_encoded_Y = process_training_data(training_data)
word2vec_model = train_word2vec_model(train_sentences_list=training_sentences)
training_data_vectors = convert_training_data_vectors(word2vec_model, train_sentences_list=training_sentences)
prediction_model = training_rf_prediction_model(training_data_vectors, label_encoded_Y)
# Out:
# 0.5893416927899686

# %%
# Seperated stuff to run model inference for an utterance
userQuery = ["how do you feel"]
user_query_vectors = convert_training_data_vectors(word2vec_model, process_user_query(userQuery))
predicted_class = prediction_model.predict(user_query_vectors)[0]
predicted_intent = target_class[list(label_encoded_Y).index(predicted_class)]
predicted_intent
# Out:
# 'quirky'

# %%
print("Predicted class: ", process_data_flow('NLU-Data-Home-Domain-Annotated-All.csv'))
# Out:
# 0.5965758379551483
# Predicted class:  hue_lightoff

# %% [markdown]
# sample_input_data.csv
#
# Utterence,Intent
#
# hi can I have an Apple Watch,service
#
# how much I will be paying monthly,service
#
# you still around,YOU_THERE
#
# are you still there,YOU_THERE
#
# you there,YOU_THERE
#
# Speak to me if you are there,YOU_THERE
#
# you around,YOU_THERE

# %% [markdown]
# https://www.kaggle.com/shoumikgoswami/ner-using-random-forest-and-crf
#
# https://towardsdatascience.com/named-entity-recognition-and-classification-with-scikit-learn-f05372f07ba2
#
# For CRFs for the entity tagging
#
# https://nanonets.com/blog/named-entity-recognition-with-nltk-and-spacy/
#
# What abou this?
# https://www.mindmeld.com/docs/userguide/intent_classifier.html
#
#
# DATA:
# https://github.com/xliuhw/NLU-Evaluation-Data/blob/master/AnnotatedData/NLU-Data-Home-Domain-Annotated-All.csv

# %% [markdown]
# NLU_data_df = load_data('NLU-Data-Home-Domain-Annotated-All.csv')

# %% [markdown]
# NLU_data_df = load_data('NLU-Data-Home-Domain-Annotated-All.csv')

# %%
# TODO
# train and save state of model (X)
# use saved model to make predictions (X)
# train/test split (is built into training_rf_prediction_model)
# train multiple classifiers (use the code above and training_rf_prediction_model to make mutli-model-training)
# k-folds
# test each one
# select best model
# save model like a pickle or whatever
# add entity tagging code (use CRFs)
# add function that combines both intent and entities for total intent

# %%
nlu_data_df = load_data('NLU-Data-Home-Domain-Annotated-All.csv')
nlu_data_df
# Out:
#        userid  answerid scenario       intent  status  \
# 0         1.0       1.0    alarm          set     NaN
# 1         1.0       2.0    alarm          set     NaN
# 2         1.0       3.0    alarm          set     NaN
# 3         1.0      31.0    audio  volume_mute     NaN
# 4         1.0      32.0    audio  volume_mute  IRR_XL
# ...       ...       ...      ...          ...     ...
# 25711     NaN     781.0  general       praise     NaN
# 25712     NaN     782.0  general       praise     NaN
# 25713     NaN     783.0  general       praise     NaN
# 25714     NaN     784.0  general       praise     NaN
# 25715     NaN     785.0  general       praise     NaN
#
#                                        answer_annotation notes  \
# 0      wake me up at [time : five am] [date : this week]   NaN
# 1      wake me up at [time : nine am] on [date : friday]   NaN
# 2           set an alarm for [time : two hours from now]   NaN
# 3                                                  quiet   NaN
# 4                                                   stop   NaN
# ...                                                  ...   ...
# 25711              that's cool, musch appreciated, olly.   NaN
# 25712                         you are hero, appreciated.   NaN
# 25713                               thanks, that's nice.   NaN
# 25714                    that's cool, thank you so much.   NaN
# 25715                     appreciate your answers, olly.   NaN
#
#       suggested_entities                    answer_normalised  \
# 0             date, time      wake me up at five am this week
# 1             date, time      wake me up at nine am on friday
# 2             date, time  set an alarm for two hours from now
# 3         player_setting                                quiet
# 4         player_setting                                 stop
# ...                  ...                                  ...
# 25711                NaN                                  NaN
# 25712                NaN                                  NaN
# 25713                NaN                                  NaN
# 25714                NaN                                  NaN
# 25715                NaN                                  NaN
#
#                                       answer  \
# 0                wake me up at 5am this week
# 1                wake me up at 9am on Friday
# 2        set an alarm for two hours from now
# 3                                Olly quiet!
# 4                                      Stop!
# ...                                      ...
# 25711  that's cool, musch appreciated, olly.
# 25712             you are hero, appreciated.
# 25713                   thanks, that's nice.
# 25714        that's cool, thank you so much.
# 25715         appreciate your answers, olly.
#
#                                                 question
# 0      Write what you would tell your PDA in the foll...
# 1      Write what you would tell your PDA in the foll...
# 2      Write what you would tell your PDA in the foll...
# 3      Write what you would tell your PDA in the foll...
# 4      Write what you would tell your PDA in the foll...
# ...                                                  ...
# 25711                                                NaN
# 25712                                                NaN
# 25713                                                NaN
# 25714                                                NaN
# 25715                                                NaN
#
# [25716 rows x 11 columns]

# %%
def process_training_data(training_data):
    # process the training data and split it between independent and dependent variables
    training_sentences = [list(map(preprocess_lower,sentence.split(" "))) for sentence in list(training_data.answer_normalised.values)]
    target_class = training_data.intent.values
    label_encoded_Y = preprocessing.LabelEncoder().fit_transform(list(target_class))
    return target_class, training_sentences, label_encoded_Y

# %%
nlu_data_df.dropna(axis=0, how='any', subset=['answer_normalised'], inplace=True)
nlu_data_df
# Out:
#        userid  answerid scenario       intent  status  \
# 0         1.0       1.0    alarm          set     NaN
# 1         1.0       2.0    alarm          set     NaN
# 2         1.0       3.0    alarm          set     NaN
# 3         1.0      31.0    audio  volume_mute     NaN
# 4         1.0      32.0    audio  volume_mute  IRR_XL
# ...       ...       ...      ...          ...     ...
# 20844  1010.0   27380.0    email        query     NaN
# 20845  1010.0   27381.0    email        query     NaN
# 20846  1010.0   27400.0    email        query     NaN
# 20847  1010.0   27401.0    email        query     NaN
# 20848  1010.0   27402.0    email        query     NaN
#
#                                        answer_annotation notes  \
# 0      wake me up at [time : five am] [date : this week]   NaN
# 1      wake me up at [time : nine am] on [date : friday]   NaN
# 2           set an alarm for [time : two hours from now]   NaN
# 3                                                  quiet   NaN
# 4                                                   stop   NaN
# ...                                                  ...   ...
# 20844                                   do i have emails   NaN
# 20845                                what emails are new   NaN
# 20846          do i have new emails from [person : john]   NaN
# 20847               has [person : john] sent me an email   NaN
# 20848                   check email from [person : john]   NaN
#
#       suggested_entities                    answer_normalised  \
# 0             date, time      wake me up at five am this week
# 1             date, time      wake me up at nine am on friday
# 2             date, time  set an alarm for two hours from now
# 3         player_setting                                quiet
# 4         player_setting                                 stop
# ...                  ...                                  ...
# 20844                NaN                     do i have emails
# 20845                NaN                  what emails are new
# 20846             person       do i have new emails from john
# 20847             person            has john sent me an email
# 20848             person                check email from john
#
#                                     answer  \
# 0              wake me up at 5am this week
# 1              wake me up at 9am on Friday
# 2      set an alarm for two hours from now
# 3                              Olly quiet!
# 4                                    Stop!
# ...                                    ...
# 20844                     Do I have emails
# 20845                 What emails are new?
# 20846       Do I have new emails from John
# 20847           Has John sent me an email?
# 20848                Check email from John
#
#                                                 question
# 0      Write what you would tell your PDA in the foll...
# 1      Write what you would tell your PDA in the foll...
# 2      Write what you would tell your PDA in the foll...
# 3      Write what you would tell your PDA in the foll...
# 4      Write what you would tell your PDA in the foll...
# ...                                                  ...
# 20844  Write what you would tell your PDA in the foll...
# 20845  Write what you would tell your PDA in the foll...
# 20846  How would you ask your PDA if you have receive...
# 20847  How would you ask your PDA if you have receive...
# 20848  How would you ask your PDA if you have receive...
#
# [20735 rows x 11 columns]

# %%
process_training_data(nlu_data_df)
# Out:
# (array(['set', 'set', 'set', ..., 'query', 'query', 'query'], dtype=object),
#  [['wake', 'me', 'up', 'at', 'five', 'am', 'this', 'week'],
#   ['wake', 'me', 'up', 'at', 'nine', 'am', 'on', 'friday'],
#   ['set', 'an', 'alarm', 'for', 'two', 'hours', 'from', 'now'],
#   ['quiet'],
#   ['stop'],
#   ['pause', 'for', 'ten', 'seconds'],
#   ['pink', 'is', 'all', 'we', 'need'],
#   ['make', 'the', 'lighting', 'bit', 'more', 'warm', 'here'],
#   ['please', 'set', 'the', 'lighting', 'suitable', 'for', 'reading'],
#   ['turn', 'the', 'lights', 'off', 'please'],
#   ['time', 'to', 'sleep'],
#   ['and', 'the', 'darkness', 'has', 'fallen'],
#   ['turn', 'off', 'the', 'light', 'in', 'the', 'bathroom'],
#   ['dim', 'the', 'lights', 'in', 'the', 'hall'],
#   ['turn', 'the', 'lights', 'off', 'in', 'the', 'bedroom'],
#   ['set', 'lights', 'to', 'twenty', 'percent'],
#   ['dim', 'the', 'lights', 'in', 'the', 'kitchen'],
#   ['make', 'a', 'room', 'darker'],
#   ['clean', 'the', 'flat'],
#   ["it's", 'dirty', 'here', 'make', 'some', 'noise'],
#   ['vacuum', 'the', 'house'],
#   ['cleaning',
#    'is',
#    'good',
#    'dust',
#    'is',
#    'so',
#    'bad',
#    'do',
#    'now',
#    'your',
#    'magic',
#    'clean',
#    'my',
#    'carpet'],
#   ['hoover', 'the', 'hallway'],
#   ['hoover', 'the', 'carpets', 'around'],
#   ['check', 'when', 'the', 'show', 'starts'],
#   ['i', 'want', 'to', 'listen', 'arijit', 'singh', 'song', 'once', 'again'],
#   ['i', 'want', 'to', 'play', 'that', 'music', 'one', 'again'],
#   ['check', 'my', 'car', 'is', 'ready'],
#   ['check', 'my', 'laptop', 'is', 'working'],
#   ['is', 'the', 'brightness', 'of', 'my', 'screen', 'running', 'low'],
#   ['i',
#    'need',
#    'to',
#    'have',
#    'location',
#    'services',
#    'on',
#    'can',
#    'you',
#    'check'],
#   ['check', 'the', 'status', 'of', 'my', 'power', 'usage'],
#   ['i', 'want', 'the', 'status', 'on', 'my', 'screen', 'brightness'],
#   ['give', 'me', 'the', 'status', 'on', 'my', 'available', 'memory'],
#   ['i', 'am', 'not', 'tired', 'i', 'am', 'actually', 'happy'],
#   ["what's", 'up'],
#   ["what's", 'the', 'time', 'in', 'australia'],
#   ['tell', 'me', 'the', 'time', 'in', 'moscow'],
#   ['tell', 'me', 'the', 'time', 'in', 'g.', 'm.', 't.', 'plus', 'five'],
#   ['list', 'most', 'rated', 'deliveroo', 'options', 'for', 'chinese', 'food'],
#   ['i', 'want', 'some', 'curry', 'to', 'go', 'any', 'recommendations'],
#   ['find', 'my', 'thai', 'takeaways', 'around', 'grassmarket'],
#   ['cancel', 'my', 'seven', 'am', 'alarm'],
#   ['remove', 'the', 'alarm', 'set', 'for', 'ten', 'pm'],
#   ['stop', 'seven', 'am', 'alarm'],
#   ['what', 'alarms', 'i', 'have', 'set'],
#   ['please', 'list', 'active', 'alarms'],
#   ['tell', 'me', 'about', 'my', 'alarms'],
#   ['whats', 'new', 'in', 'london'],
#   ['tell', 'me', 'latest', 'bbc', 'news'],
#   ['whats', 'happening', 'in', 'football', 'today'],
#   ['please', 'play', 'yesterday', 'from', 'beattles'],
#   ["i'd", 'like', 'to', 'hear', "queen's", 'barcelona'],
#   ['play', 'me', 'barcelona', 'by', 'queen'],
#   ['i', 'like', 'rock', 'music'],
#   ['my', 'favourite', 'music', 'band', 'is', 'queen'],
#   ['i', 'like', 'senatra', 'songs'],
#   ['start', 'playing', 'music', 'from', 'favourites'],
#   ['please', 'play', 'my', 'best', 'music'],
#   ['play', 'something', 'from', 'recent', 'playlist'],
#   ["what's", 'the', 'band', 'is', 'playing', 'now'],
#   ["who's", 'current', "music's", 'author'],
#   ["what's", 'that', 'the', 'album', 'is', 'current', 'music', 'from'],
#   ["i'm", 'really', 'enjoying', 'this', 'song'],
#   ['the', 'song', 'you', 'are', 'playing', 'is', 'amazing'],
#   ['this', 'is', 'one', 'of', 'the', 'best', 'songs', 'for', 'me'],
#   ['set', 'lights', 'brightness', 'higher'],
#   ['make', 'lights', 'brightener'],
#   ['please', 'raise', 'the', 'lights', 'to', 'ma', '<unk>'],
#   ['hey', 'start', 'vacuum', 'cleaner', 'robot'],
#   ['enable', 'cleaner', 'robot'],
#   ['turn', 'cleaner', 'robot', 'on'],
#   ['tell', 'me', "today's", 'date'],
#   ['what', 'date', 'is', 'it', 'today'],
#   ["what's", 'the', 'date', 'is', 'currently'],
#   ['please', 'order', 'some', 'sushi', 'for', 'dinner'],
#   ['hey', "i'd", 'like', 'you', 'to', 'order', 'burger'],
#   ['could', 'you', 'order', 'sushi', 'for', 'tonight', 'dinner'],
#   ['whats', 'with', 'my', 'dinner', 'order'],
#   ['can', 'i', 'order', 'takeaway', 'dinner', 'from', "byron's"],
#   ['does', "byron's", 'supports', 'takeaways'],
#   ['set', 'an', 'alarm', 'for', 'twelve'],
#   ['set', 'an', 'alarm', 'forty', 'minutes', 'from', 'now'],
#   ['set', 'alarm', 'for', 'eight', 'every', 'weekday'],
#   ['is', 'it', 'raining'],
#   ['is', 'it', 'going', 'to', 'rain'],
#   ['is', 'it', 'currently', 'snowing'],
#   ['whats', 'the', 'weeks', 'forecast'],
#   ['whats', 'this', 'weeks', 'weather'],
#   ['tell', 'me', 'the', 'weather', 'this', 'week'],
#   ['tell', 'me', 'bbc', 'news'],
#   ['whats', 'the', 'news', 'on', 'bbc', 'news'],
#   ['what', 'is', 'the', "bbc's", 'latest', 'news'],
#   ['play', 'hurts', 'like', 'heaven'],
#   ['play', 'a', 'song', 'i', 'like'],
#   ['put', 'on', 'cannibal', 'queen'],
#   ['play', 'daft', 'punk'],
#   ['put', 'on', 'some', 'coldplay'],
#   ['play', 'some', 'david', 'bowie'],
#   ['loop', 'this', 'track'],
#   ['shuffle', 'this', 'playlist'],
#   ['set', 'the', 'volume', 'to', 'low'],
#   ['whats', 'playing'],
#   ['what', 'music', 'is', 'this'],
#   ['tell', 'me', 'the', 'artist', 'of', 'this', 'song'],
#   ['make', 'me', 'laugh'],
#   ['tell', 'me', 'a', 'good', 'joke'],
#   ['send', 'a', 'giggle', 'my', 'way'],
#   ['tell', 'me', 'a', 'joke'],
#   ['chear', 'me', 'up'],
#   ['whats', 'the', 'day', 'today'],
#   ['thats', 'the', 'date'],
#   ['tell', 'me', 'about', 'today'],
#   ['order', 'a', 'pizza'],
#   ['order', 'me', 'a', 'byron', 'from', 'deliveroo'],
#   ['order', 'a', 'takeaway'],
#   ['when', 'is', 'my', 'order', 'arriving'],
#   ['how', 'long', 'until', 'my', 'takeaway'],
#   ["domino's", 'delivery', 'status'],
#   ["what's", 'playing'],
#   ['tell', 'me', 'the', 'name', 'of', 'the', 'song'],
#   ['which', 'song', 'is', 'that'],
#   ['play', 'my', 'jazz', 'playlist'],
#   ['start', 'my', 'jazz', 'playlist'],
#   ['play', 'my', 'favourite', 'playlist'],
#   ["that's", 'a', 'good', 'song'],
#   ['i', "don't", 'like', 'it'],
#   ['i', 'like', 'it'],
#   ['i', 'like', 'jazz'],
#   ['can', 'you', 'play', 'some', 'jazz'],
#   ['i', 'like', 'to', 'listen', 'to', 'jazz'],
#   ['this', 'song', 'was', 'very', 'good'],
#   ['i', 'like', 'this', 'song'],
#   ['play', 'it', 'again', 'please'],
#   ['change', 'the', 'volume'],
#   ['enable', 'shuffle'],
#   ['save', 'settings'],
#   ['set', 'brightness', 'to', 'fifty', 'percent'],
#   ['turn', 'down', 'the', 'brightness'],
#   ['reduce', 'the', 'brightness'],
#   ['lower', 'the', 'lights'],
#   ['decrease', 'brightness'],
#   ['dim', 'the', 'lights'],
#   ['make', 'me', 'a', 'coffee'],
#   ['i', 'need', 'a', 'coffee'],
#   ['i', 'fancy', 'some', 'coffee', 'now'],
#   ['how', 'are', 'you'],
#   ['hey', 'hey'],
#   ['can', 'they', 'provide', 'takeaway'],
#   ['can', 'they', 'do', 'delivery'],
#   ['do', 'they', 'deliver', 'home'],
#   ['set', 'alarm', 'at', 'ten', 'am'],
#   ['set', 'alarm', 'tomorrow', 'at', 'six', 'am'],
#   ['set', 'wake', 'up', 'thursday', 'seven', 'am'],
#   ['tell', 'me', 'latest', 'technology', 'news'],
#   ['tell', 'me', 'some', 'business', 'news'],
#   ['tell', 'me', 'international', 'news'],
#   ['tell', 'me', 'the', 'weather'],
#   ['what', 'is', 'the', 'weather', 'now'],
#   ['is', 'it', 'raining', 'now'],
#   ['play', 'my', 'rock', 'playlist'],
#   ['turn', 'on', 'my', 'michael', 'jackson', 'playlist'],
#   ['play', 'michael', 'jackson', 'from', 'my', 'playlist'],
#   ['turn',
#    'on',
#    'my',
#    'playlist',
#    'and',
#    'play',
#    'third',
#    'song',
#    'in',
#    'the',
#    'queue'],
#   ['play', 'last', 'song', 'from', 'my', 'favourite', 'playlist'],
#   ['turn', 'up', 'the', 'volume'],
#   ['volume', 'up'],
#   ['mute', 'volume'],
#   ['turn', 'on', 'the', 'plug'],
#   ['switch', 'on', 'the', 'plug'],
#   ['turn', 'on', 'my', 'plug'],
#   ['tell', 'me', 'some', 'joke'],
#   ['do', 'you', 'know', 'any', 'joke'],
#   ['what', 'is', 'the', 'time'],
#   ['tell', 'me', 'the', 'time'],
#   ['what', 'time', 'is', 'it'],
#   ['does', 'dominos', 'do', 'takeaway'],
#   ['does',
#    'my',
#    'favourite',
#    'pizza',
#    'place',
#    'available',
#    'for',
#    'takeaway'],
#   ['can', 'i', 'order', 'takeaway', 'from', 'spanish', 'place'],
#   ['delete', 'the', 'alarm', 'i', 'just', 'set'],
#   ['remove', 'the', 'alarm'],
#   ['show', 'me', 'the', 'alarms', 'i', 'set'],
#   ['do', 'i', 'have', 'any', 'alarms'],
#   ['show', 'alarms'],
#   ["how's", 'the', 'weather', 'like', 'in', 'beijing'],
#   ['tell', 'me', 'the', 'weather', 'in', 'shanghai'],
#   ['please', 'set', 'the', 'lights', 'to', 'green'],
#   ['please', 'make', 'the', 'lights', 'reading', 'friendly'],
#   ['please', 'make', 'the', 'lights', 'watching', 'friendly'],
#   ['make', 'the', 'room', 'brighter'],
#   ['and', 'the', 'light', 'began'],
#   ["what's", 'date', 'today'],
#   ['what', 'day', 'is', 'today'],
#   ['tell', 'me', 'a', 'date'],
#   ['how', 'is', 'the', 'weather', 'like', 'today'],
#   ['is', 'it', 'raining', 'outside'],
#   ['should', 'i', 'bring', 'an', 'umbrella', 'tomorrow'],
#   ['play', 'music', 'from', 'my', 'rock', 'list'],
#   ['change', 'the', 'lights', 'into', 'green'],
#   ['add', 'this', 'song', 'to', 'my', 'favorite', 'list'],
#   ['what', 'is', 'this', 'song'],
#   ['lights', 'off'],
#   ['clean', 'the', 'floor', 'please'],
#   ['turn', 'on', 'the', 'rice', 'cooker', 'socket'],
#   ['turn', 'off', 'the', 'rice', 'cooker', 'socket'],
#   ['what', 'time', 'is', 'it', 'in', 'las', 'vegas'],
#   ['what', 'time', 'is', 'it', 'in', 'beijing'],
#   ['could',
#    'you',
#    'please',
#    'help',
#    'me',
#    'to',
#    'order',
#    'some',
#    'sushi',
#    'from',
#    'deliveroo'],
#   ['set', 'an', 'alarm', 'at', 'six', 'in', 'the', 'morning'],
#   ['set', 'an', 'alarm', 'for', 'four', 'in', 'the', 'afternoon'],
#   ['alert', 'me', 'at', 'three', 'pm', 'to', 'goto', 'the', 'concert'],
#   ['do', 'i', 'have', 'an', 'alarm', 'set', 'for', 'morning', 'flight'],
#   ['did',
#    'i',
#    'set',
#    'an',
#    'alarm',
#    'to',
#    'wake',
#    'up',
#    'in',
#    'the',
#    'morning'],
#   ['are', 'there', 'any', 'alarms'],
#   ["what's", 'the', 'weather', 'in', 'napels'],
#   ['is', 'it', 'raining', 'in', 'barcelona'],
#   ['sunny', 'in', 'oslo'],
#   ['will', 'it', 'rain', 'today'],
#   ["what's", 'going', 'on', 'outside'],
#   ["what's", 'happening', 'in', 'america'],
#   ["what's", 'going', 'on', 'in', 'the', 'world'],
#   ["what's", 'happening', 'in', 'cambridge'],
#   ['show', 'me', 'some', 'news', 'from', 'bbc'],
#   ['play', 'cnn', 'news'],
#   ['hackernews'],
#   ['play', 'me', 'some', 'hihop'],
#   ['i', 'feel', 'like', 'jazz', 'right', 'now', 'how', 'about', 'you'],
#   ['death', 'metal', 'now'],
#   ['play', 'a', 'good', 'track', 'from', 'my', 'favourite', 'jazz', 'player'],
#   ['what', 'music', 'do', 'i', 'usually', 'like', 'after', 'work'],
#   ['play', 'music', 'from', 'my', 'fav', 'pianist'],
#   ['i', "can't", 'hear', 'you'],
#   ["you're", 'too', 'loud'],
#   ['i', 'can', 'barely', 'hear', 'you'],
#   ['turn', 'the', 'lights', 'blue'],
#   ["let's", 'have', 'the', 'lights', 'blue'],
#   ['make', 'the', 'lights', 'shine', 'blue'],
#   ['good', 'night', 'lights', 'off'],
#   ["it's", 'awfully', 'dark', 'here'],
#   ['make', 'the', 'lights', 'brighter'],
#   ["it's", 'too', 'dark', 'i', "can't", 'even', 'see', 'my', 'hands'],
#   ["what's", 'the', 'time'],
#   ['is', 'it', 'five', 'o', 'clock', 'already'],
#   ["what's", 'the', 'time', 'in', 'new', 'york'],
#   ["what's", 'the', 'time', 'in', 'tokyo', 'now'],
#   ['is', 'it', 'night', 'time', 'in', 'peru'],
#   ['what', 'is', 'the', 'song'],
#   ['what',
#    'the',
#    'singer',
#    'meant',
#    'by',
#    'the',
#    'title',
#    'of',
#    'the',
#    'song',
#    'bohemian',
#    'rhapsody'],
#   ['who', 'covered', 'the', 'song', 'one', 'more', 'cup', 'of', 'coffee'],
#   ['what', 'is', 'the', 'weather', 'in', 'paris'],
#   ['what', 'is', 'the', 'weather', 'like', 'in', 'toronto'],
#   ['what', 'is', "today's", 'forecast', 'for', 'berlin'],
#   ['what', 'is', 'the', 'current', 'state', 'of', 'brexit', 'negotiations'],
#   ['what',
#    'is',
#    'the',
#    'exchange',
#    'rate',
#    'of',
#    'us',
#    'dollar',
#    'to',
#    'pound',
#    'sterling'],
#   ['who',
#    'is',
#    'going',
#    'to',
#    'win',
#    'the',
#    'next',
#    'elections',
#    'in',
#    'the',
#    'france'],
#   ['do', 'you', 'expect', 'sun', 'on', 'sunday'],
#   ['is', 'it', 'going', 'to', 'rain', 'in', 'the', 'evening'],
#   ['is', 'it', 'going', 'to', 'be', 'windy', 'tomorrow'],
#   ['light', 'up', 'the', 'lights', 'in', 'the', 'kitchen'],
#   ['brighten', 'the', 'lamp', 'next', 'to', 'the', 'sofa'],
#   ['lighten', 'the', 'light'],
#   ['it',
#    'is',
#    'five',
#    'hundred',
#    'and',
#    'forty',
#    'five',
#    'am',
#    'in',
#    'liverpool',
#    'what',
#    'time',
#    'is',
#    'now',
#    'new',
#    'york'],
#   ['given',
#    'it',
#    'is',
#    'four',
#    'hundred',
#    'and',
#    'thirty',
#    'five',
#    'pm',
#    'in',
#    'london',
#    'what',
#    'time',
#    'is',
#    'it',
#    'in',
#    'melbourne'],
#   ['what', 'time', 'is', 'it', 'in', 'moscow', 'now'],
#   ['start', 'a', 'vacuum', 'cleaner'],
#   ['vacuum', 'the', 'kitchen'],
#   ['turn', 'on', 'the', 'vacuum', 'cleaner'],
#   ['what', 'is', 'happening', 'in', 'the', 'world'],
#   ['tell', 'me', 'the', 'news'],
#   ['tell', 'me', "today's", "newspaper's", 'headlines'],
#   ['play', 'a', 'nirvana', 'playlist'],
#   ['shuffle', 'songs', 'by', 'coldplay'],
#   ['play', 'chopin'],
#   ['what', 'is', 'the', 'weather'],
#   ['what', 'is', 'the', 'forecast', 'for', 'today'],
#   ['what', 'is', 'the', 'weather', 'like'],
#   ['hey', 'what', 'are', 'you', 'up', 'to'],
#   ['how', 'are', 'you', 'doing'],
#   ['morning', "what's", 'up'],
#   ['order', 'a', 'pizza', 'from', 'pizza', 'express'],
#   ['i',
#    'would',
#    'like',
#    'to',
#    'have',
#    'a',
#    'sushi',
#    'can',
#    'you',
#    'order',
#    'me',
#    'a',
#    'lunch'],
#   ['order',
#    'a',
#    'takeaway',
#    'sandwich',
#    'and',
#    'soup',
#    'from',
#    'the',
#    "italian's"],
#   ['how', 'many', 'days', 'are', 'left', 'in', 'this', 'year'],
#   ['what', 'day', 'is', 'new', "year's", 'eve', 'this', 'year'],
#   ['what', 'day', 'is', 'memorial', 'day', 'this', 'year'],
#   ["it's", 'too', 'dark', 'here'],
#   ['increase', 'brightness', 'by', 'twenty', 'percent'],
#   ['set', 'lights', 'to', 'full', 'power'],
#   ['please', 'be', 'quiet', 'for', 'another', 'hour'],
#   ['mute'],
#   ['do', 'not', 'speak', 'today'],
#   ['is', 'it', 'going', 'to', 'rain', 'tomorrow'],
#   ['tell',
#    'me',
#    'the',
#    'weather',
#    'in',
#    'barcelona',
#    'in',
#    'two',
#    'days',
#    'from',
#    'now'],
#   ['shall', 'i', 'get', 'an', 'umbrella', 'tomorrow'],
#   ['disable', 'my', 'okug'],
#   ['enable', 'my', 'plug'],
#   ['turn', 'on', 'the', 'smart', 'charger'],
#   ['tell', 'me', 'some', 'fresh', 'info', 'from', 'daily', 'mail'],
#   ['what',
#    'new',
#    'is',
#    'happening',
#    'in',
#    'business',
#    'according',
#    'to',
#    'the',
#    'economist'],
#   ['tell', 'me', 'the', 'news', 'in', 'technology', 'from', 'engadget'],
#   ['happy'],
#   ['evening'],
#   ['sunday'],
#   ['one', 'dance'],
#   ['seven', 'years'],
#   ['cheap', 'thrills'],
#   ['quieter'],
#   ['softer'],
#   ['silent'],
#   ['what', 'is', 'the', 'weather', 'condition', 'in', 'ny'],
#   ['i', 'wish', 'to', 'know', 'the', 'weather', 'in', 'sf'],
#   ['is', 'it', 'snowing', 'in', 'california'],
#   ['use', 'shortcut'],
#   ['button'],
#   ['menu'],
#   ['yo', 'i', 'need', 'a', 'coffee', 'now'],
#   ['start', 'the', 'coffee', 'machine'],
#   ['get', 'a', 'cup', 'of', 'coffee', 'ready', 'now'],
#   ['how', 'will', 'be', 'the', 'weather', 'tomorrow'],
#   ['will', 'it', 'be', 'rainy', 'tomorrow'],
#   ['what', 'will', 'be', 'the', 'temperature', 'out', 'there', 'tomorrow'],
#   ['what', 'is', 'tomorrows', 'weather', 'predicitons'],
#   ['will', 'it', 'rain', 'tomorrow'],
#   ['will', 'there', 'be', 'snow', 'tomorrow'],
#   ['find', 'out', 'if', 'the', 'restaurant', 'does', 'takeaway', 'orders'],
#   ['search', 'if', 'the', 'restaurant', 'does', 'take', 'out'],
#   ['is', 'there', 'a', 'takeout', 'menu', 'at', 'the', 'restaurant'],
#   ['what',
#    'day',
#    'of',
#    'the',
#    'week',
#    'is',
#    'the',
#    'twenty',
#    'second',
#    'march'],
#   ['twenty', 'ninth', 'march', 'comes', 'on', 'what', 'day'],
#   ['what', 'day', 'of', 'the', 'week', 'is', 'first', 'april'],
#   ["what's", 'my', 'next', 'alarm'],
#   ['please', 'tell', 'me', 'my', 'alarms'],
#   ['what', 'time', 'will', 'my', 'alarm', 'go', 'off', 'today'],
#   ['can', 'you', 'tell', 'me', 'the', 'time'],
#   ['what', 'is', 'the', 'current', 'time'],
#   ['play', 'the', 'track', 'eight', 'from', 'google', 'play', 'music'],
#   ['play', 'the', 'second', 'song', 'from', "anirudh's", 'song'],
#   ['play', 'a', 'song', 'randomly', 'from', 'my', 'playlist'],
#   ['what', 'is', 'the', 'current', 'date'],
#   ['is', 'it', 'monday', 'today'],
#   ['please', 'tell', 'me', 'the', 'latest', 'news'],
#   ["what's", 'going', 'on', 'in', 'the', 'news'],
#   ['what', 'are', "today's", 'top', 'news', 'stories'],
#   ["what's", 'the', 'weather', 'like', 'in', 'new', 'york', 'city'],
#   ["what's", 'the', 'humidity', 'level'],
#   ['switch', 'off', 'the', 'lights'],
#   ['can', 'you', 'please', 'switch', 'of', 'the', 'lights'],
#   ['i',
#    'want',
#    'the',
#    'light',
#    'switched',
#    'off',
#    'can',
#    'you',
#    'do',
#    'it',
#    'for',
#    'me'],
#   ['go', 'to', 'menu'],
#   ['choose', 'that', 'music', 'player'],
#   ['play', 'the', 'song'],
#   ['tell',
#    'me',
#    'if',
#    'the',
#    'following',
#    'is',
#    'true',
#    'about',
#    'the',
#    'weather'],
#   ['is', 'it', '<unk>', 'here', 'now'],
#   ['check', 'the', 'weather', 'app', 'to', 'see', 'if'],
#   ['can', 'save', 'this', 'music', 'in', 'my', 'playlist'],
#   ['how', 'about', 'you', 'save', 'this', 'music'],
#   ['i',
#    'want',
#    'the',
#    'music',
#    'to',
#    'be',
#    'saved',
#    'can',
#    'you',
#    'do',
#    'it',
#    'for',
#    'me'],
#   ['please', 'play', 'games', 'by', 'disturbed'],
#   ['please',
#    'open',
#    'my',
#    'music',
#    'application',
#    'and',
#    'play',
#    'games',
#    'by',
#    'disturbed'],
#   ['please', 'play', 'the', 'song', 'games', 'by', 'disturbed'],
#   ['turn', 'off', 'the', 'light', 'in', 'the', 'leaving', 'room'],
#   ['turn', 'the', 'security', 'light', 'off'],
#   ['turn', 'off', 'the', 'garage', 'light'],
#   ['check', 'for', 'hot', 'news', 'in', 'times', 'of', 'india'],
#   ["what's", 'sensational', 'in', 'time', 'of', 'india'],
#   ['any', 'death', 'news', 'in', 'times', 'of', 'india'],
#   ['follow', 'the', 'following', 'news', 'topic'],
#   ['keep', 'me', 'posted', 'on', '<unk>', 'subject', 'in', 'the', 'news'],
#   ['let',
#    'me',
#    'know',
#    'as',
#    'soon',
#    'as',
#    'there',
#    'is',
#    'more',
#    'news',
#    'on',
#    '<unk>'],
#   ['turn', 'off', 'the', 'smart', 'plug'],
#   ['turn', 'the', 'smart', 'plug', 'on'],
#   ['switch', 'the', 'smart', 'plug', 'socket'],
#   ['play', 'a', 'random', 'song', 'from', 'my', 'playlist'],
#   ['play', 'a', 'song', 'from', 'my', 'favourites'],
#   ['play', 'a', 'retro', 'song', 'in', 'my', 'playlist'],
#   ['what',
#    'time',
#    'is',
#    'twelve',
#    'pm',
#    'eastern',
#    'time',
#    'in',
#    'pacific',
#    'time'],
#   ['if',
#    'it',
#    'is',
#    'noon',
#    'in',
#    'virginia',
#    'what',
#    'time',
#    'is',
#    'it',
#    'in',
#    'california'],
#   ['what',
#    'is',
#    'the',
#    'time',
#    'difference',
#    'between',
#    'eastern',
#    'time',
#    'and',
#    'pacific',
#    'time'],
#   ['play', 'why', 'do', 'you', 'sing', 'by', 'kirk', 'franklin'],
#   ['play', 'any', 'song', 'by', 'joe', 'prsaise'],
#   ['play', 'every', 'praise'],
#   ['will', 'it', 'snow', 'tomorrow'],
#   ['will', 'it', 'be', 'warm', 'tomorrow'],
#   ['remove', 'the', 'first', 'alarm'],
#   ['disable', 'the', 'first', 'alarm'],
#   ['delete', 'the', 'first', 'aarm'],
#   ['play', 'some', '<unk>'],
#   ['start', 'playing'],
#   ['music', 'please'],
#   ['can', 'you', 'change', 'the', 'light', 'colors', 'in', 'the', 'house'],
#   ['can', 'you', 'shuffle', 'the', 'light', 'colors', 'in', 'the', 'house'],
#   ['can',
#    'you',
#    'change',
#    'the',
#    'light',
#    'colors',
#    'into',
#    'dark',
#    'in',
#    'the',
#    'house'],
#   ['play', 'my', 'r.', 'n.', 'b.', 'playlist'],
#   ['i', 'would', 'like', 'to', 'listen', 'to', 'pop', 'music', 'please'],
#   ['can', 'you', 'play', 'rock', 'music', 'for', 'the', 'next', 'hour'],
#   ['what', 'alarms', 'do', 'i', 'have', 'set'],
#   ['read', 'me', 'my', 'alarms'],
#   ['what', 'time', 'are', 'my', 'alarms', 'set', 'for'],
#   ['can', 'you', 'tell', 'me', 'a', 'joke'],
#   ['tell', 'me', 'a', 'funny', 'joke'],
#   ['change', 'my', 'room', 'lights', 'to', 'blue'],
#   ['change', 'my', 'room', 'lights', 'to', 'some', 'romantic', 'colour'],
#   ['change',
#    'my',
#    'room',
#    'lights',
#    'so',
#    'that',
#    'i',
#    'can',
#    'get',
#    'a',
#    'good',
#    'sleep'],
#   ['set', 'an', 'alarm', 'for', 'me', 'at', 'eight', 'am'],
#   ['make', 'an', 'alarm', 'for', 'four', 'pm'],
#   ['make',
#    'me',
#    'a',
#    'wake',
#    'up',
#    'alarm',
#    'for',
#    'eight',
#    'hundred',
#    'and',
#    'forty',
#    'five',
#    'am'],
#   ['go', 'to', 'alarm', 'on', 'menu'],
#   ['change', 'the', 'time'],
#   ['set', 'alarm'],
#   ['what', 'are', 'the', 'latest', 'news'],
#   ['what', 'are', 'the', 'breaking', 'news'],
#   ['what', 'are', 'the', 'hearhrob', 'news'],
#   ['turn', 'on', 'the', 'plug', 'socket', 'one'],
#   ['power', 'up', 'the', 'plug', 'socket', 'one'],
#   ['power', 'down', 'the', 'plug', 'socket', 'one'],
#   ['turn', 'off', 'the', 'lights', 'in', 'the', 'bathroom'],
#   ['turn', 'off', 'the', 'bathroom', 'lights'],
#   ['lights', 'off', 'bathroom'],
#   ['what', 'is', 'the', 'weather', 'like', 'right', 'now'],
#   ["what's", 'the', 'weather', 'like', 'on', 'friday'],
#   ['how', 'warm', 'is', 'it', 'outside', 'right', 'now'],
#   ['what', 'is', 'the', 'weather', 'right', 'now', 'outside'],
#   ['how', 'warm', 'is', 'it', 'right', 'now', 'outside'],
#   ['is', 'it', 'cold', 'outside', 'right', 'now'],
#   ['what', 'day', 'is', 'it', 'today'],
#   ['what', 'day', 'of', 'the', 'month', 'is', 'next', 'tuesday'],
#   ['play', 'bad', 'religion', 'folder'],
#   ['open', 'bad', 'religion', 'folder'],
#   ['play', 'all', 'albums', 'by', 'bad', 'religion'],
#   ['is', 'it', 'going', 'to', 'rain', 'today'],
#   ['should', 'i', 'wear', 'a', 'jacket', 'today'],
#   ['read', 'me', 'new', 'headlines'],
#   ['what', 'are', 'the', 'latest', 'news', 'headlines'],
#   ["what's", 'happening', 'in', 'the', 'news'],
#   ['raise', 'volume'],
#   ['disable', 'shuffle'],
#   ['repeat', 'album'],
#   ['play', 'metallica'],
#   ['what', 'playlists', 'do', 'you', 'have', 'for', 'pop', 'music'],
#   ['play', 'old', 'fashioned', 'christmas', 'music'],
#   ['run', 'coffee', 'maker'],
#   ['make', 'coffee'],
#   ['access', 'coffee', 'maker', 'begin', 'process'],
#   ['get', 'me', 'the', 'latest', 'stock', 'price', 'for', 'costco'],
#   ['who',
#    'is',
#    'currently',
#    'leading',
#    'in',
#    'the',
#    'parliamentary',
#    'election'],
#   ['which',
#    'are',
#    'the',
#    'games',
#    'lined',
#    'up',
#    'for',
#    'this',
#    'weekend',
#    'in',
#    'the',
#    'english',
#    'premier',
#    'league'],
#   ['what', 'is', "today's", 'date'],
#   ['what', 'is', 'the', 'date', 'and', 'time'],
#   ['change', 'the', 'lights', 'in', 'the', 'kitfchen', 'to', 'blue'],
#   ['fi', '<unk>', 'the', 'lights', 'in', 'the', 'living', 'room', 'to', 'red'],
#   ['change', 'the', 'bedroom', 'lights', 'to', 'green'],
#   ['thumbs', 'down'],
#   ['i', "don't", 'like', 'this', 'band'],
#   ['can', 'you', 'speak', 'a', 'little', 'louder'],
#   ['i',
#    'am',
#    'unable',
#    'to',
#    'hear',
#    'you',
#    'can',
#    'you',
#    'speak',
#    'little',
#    'loud'],
#   ['please', 'speak', 'loud'],
#   ['i', 'want', 'to', 'listen', 'to', 'rock', 'music'],
#   ['i', 'want', 'to', 'listen', 'classical', 'music'],
#   ['i', 'want', 'to', 'listen', 'jazz'],
#   ['what', 'day', 'is', 'it'],
#   ['tell', 'me', 'the', 'date', 'and', 'the', 'time'],
#   ["what's", 'the', 'date'],
#   ['brighten', 'my', 'bedroom', 'light'],
#   ['turn', 'up', 'the', 'light'],
#   ['change', 'the', 'lights', 'to', 'dim'],
#   ['turn', 'off', 'light'],
#   ['turn', 'off', 'lamp'],
#   ['lights', 'out'],
#   ['play', 'songs', 'by', 'sia'],
#   ['play', 'the', 'weeknd'],
#   ['open', 'songs', 'by', 'prince'],
#   ['what', 'mistakes', 'do', 'you', 'usually', 'make'],
#   ['what', 'things', "can't", 'you', 'do'],
#   ['find', 'news', 'about', 'brexit'],
#   ['open', 'news', 'about', 'bp', 'oil'],
#   ['find', 'me', 'news', 'about', 'trumps', 'speech'],
#   ['tell', 'me', 'the', 'hour'],
#   ['what', 'time', 'is', 'it', 'in', 'the', 'other', 'time', 'zones'],
#   ['what', 'time', 'zone', 'is', 'arizona'],
#   ['what', 'time', 'is', 'it', 'in', 'the', 'east'],
#   ['what', 'is', 'the', 'name', 'of', 'song'],
#   ['who', 'is', 'the', 'singer', 'of', 'song'],
#   ['what', 'is', 'the', 'length', 'of', 'song'],
#   ['what', 'time', 'is', 'it', 'in', 'new', 'york', 'city'],
#   ['what', 'is', 'the', 'time', 'in', 'india', 'right', 'now'],
#   ['what', 'time', 'is', 'it', 'right', 'now', 'in', 'australia'],
#   ['what', 'is', 'the', 'temperature', 'outside'],
#   ['is', 'it', 'hot', 'outside'],
#   ['is', 'is', 'cold', 'outside'],
#   ['whats', 'a', 'silly', 'joke', 'you', 'know'],
#   ['whats', 'a', 'good', 'joke'],
#   ['select', 'the', 'music', 'player'],
#   ['play', 'a', 'genre', 'of', 'music'],
#   ['change', 'the', 'light', 'color', 'to', 'blue'],
#   ['confirm', 'whether', 'the', 'color', 'is', 'blue'],
#   ['change', 'the', 'light', 'color', 'to', 'red'],
#   ['what', 'time', 'is', 'it', 'in', 'des', 'moines'],
#   ['whats', 'the', 'time', 'in', 'denver'],
#   ['hows', 'the', 'time', 'in', 'key', 'largo'],
#   ['select', 'the', 'weather', 'option'],
#   ['find', 'a', 'weather'],
#   ['silence', 'please'],
#   ['speakers', 'off'],
#   ['quiet', 'please'],
#   ['plau', 'tonic'],
#   ['play', 'songs', 'bu', 'adele'],
#   ['open', 'songs', 'from', 'major', 'lazer'],
#   ['confirm', 'the', 'alarm', 'time'],
#   ['what', 'alarms', 'are', 'set'],
#   ['which', 'alarms', 'do', 'i', 'have'],
#   ['do', 'i', 'have', 'an', 'alarm', 'set'],
#   ['by', 'proper', 'formula'],
#   ['by', 'get', 'marks'],
#   ['by', 'our', 'scores'],
#   ['can', 'you', 'mute', 'when', 'i', 'am', 'not', 'home'],
#   ['must', 'yourself', 'when', 'i', 'am', 'in', 'a', 'meeting'],
#   ['mute', 'for', 'the', 'next', 'hour', 'please'],
#   ['play', 'neverland', 'by', 'metallica'],
#   ['play', 'my', 'favorite', 'song'],
#   ['play', 'my', 'most', 'played', 'songs'],
#   ['whats', 'the', 'time'],
#   ['what', 'time', 'is', 'it', 'right', 'now'],
#   ['give', 'me', 'the', 'time'],
#   ['its', 'not', 'possible'],
#   ['its', 'not', 'good'],
#   ['its', 'very', 'dangerous', 'one'],
#   ['how',
#    'much',
#    'time',
#    'it',
#    'will',
#    'take',
#    'to',
#    'prepare',
#    'the',
#    'order'],
#   ['prepare', 'the', 'order', 'as', 'soon', 'as', 'possible'],
#   ['it', 'is', 'already', 'late'],
#   ['tell', 'me', 'random', 'joke'],
#   ['do', 'you', 'know', 'any', 'jokes'],
#   ["what's", 'your', 'favorite', 'joke'],
#   ['by', 'switch', 'off'],
#   ['by', 'remote', 'sensor'],
#   ['by', 'main', 'power', 'off'],
#   ['what', 'are', 'the', 'latest', 'world', 'news'],
#   ['please', 'tell', 'me', 'some', 'international', 'news'],
#   ['what',
#    'are',
#    'the',
#    'latest',
#    'international',
#    'utes',
#    'in',
#    'the',
#    'world'],
#   ['set', 'an', 'alarm', 'for', 'nine', 'am'],
#   ['set', 'a', 'wake', 'up', 'call', 'for', 'ten', 'am'],
#   ['i', 'need', 'a', 'reminder', 'alarm', 'at', 'one'],
#   ['make', 'an', 'alarm', 'for', 'three', 'pm'],
#   ['turn', 'on', 'an', 'alarm', 'for', 'nine', 'am'],
#   ['set', 'an', 'alarm', 'for', 'one', 'pm'],
#   ['search', 'the', 'album', 'name', 'with', 'katy', 'perry'],
#   ['play', 'the', 'song', 'sung', 'by', 'katy', 'perry'],
#   ['play', 'the', 'song', 'immediately'],
#   ['its', 'peaceful'],
#   ["what's", 'the', 'funniest', 'joke'],
#   ['tell', 'me', 'a', 'dirty', 'joke'],
#   ['choose', 'music', 'player'],
#   ['paly', 'the', 'playlist'],
#   ['please',
#    'increase',
#    'the',
#    'volume',
#    'of',
#    'the',
#    'music',
#    'hips',
#    "don't",
#    'lie'],
#   ['please', 'lower', 'the', 'shuffle', 'rate', 'of', 'hips', "don't", 'lie'],
#   ['please', 'repeat', 'that', 'music', 'again', 'of', 'akon'],
#   ['what', 'song', 'is', 'playing'],
#   ['who', 'is', 'singing', 'this', 'song'],
#   ['email', 'me', 'the', 'lyrics', 'to', 'this', 'song'],
#   ['turn', 'the', 'lights', 'off', 'in', 'the', 'living', 'room'],
#   ['please', 'set', 'the', 'lights', 'off', 'in', 'the', 'living', 'room'],
#   ['light', 'off', 'living', 'room'],
#   ['play', 'mf', 'doom', 'anything'],
#   ['can', 'i', 'get', 'some', 'background', 'music'],
#   ['how', 'many', 'alarms', 'are', 'listed'],
#   ['do', 'i', 'have', 'any', 'alarms', 'set', 'for', 'tomorrow'],
#   ["what's", 'the', 'alarm', 'situation', 'for', 'tomorrow'],
#   ['turn', 'off', 'eight', 'am', 'alarm'],
#   ['cancel', 'my', 'eight', 'am', 'alarm'],
#   ['get', 'rid', 'of', 'my', 'eight', 'am', 'alarm'],
#   ['light', 'color', 'change'],
#   ['change', 'light', 'color'],
#   ['change', 'color', 'of', 'lights'],
#   ["what's", 'the', 'temperature'],
#   ['how', 'warm', 'is', 'it'],
#   ['how', 'cold', 'is', 'it'],
#   ['how', 'many', "birthday's", 'are', 'on', 'twenty', 'third'],
#   ['is', 'it', 'second', 'saturday', 'on', 'twelfth'],
#   ['is', 'there', 'christmas', 'on', 'twenty', 'second'],
#   ['what', 'is', 'the', 'date'],
#   ['increase', 'volume'],
#   ['repeat', 'same', 'song', 'for', 'ten', 'times'],
#   ['play', 'only', 'particular', 'singer', 'songs'],
#   ['play', 'all', 'by', 'playlist'],
#   ['play', 'one', 'through', 'ten', 'on', 'list'],
#   ['please', 'play', 'artist', 'first', 'in', 'queue'],
#   ['turn', 'off', 'one', 'light', 'on', 'porch'],
#   ['please', 'turn', 'off', 'the', 'light'],
#   ['turn', 'the', 'lamp', 'off'],
#   ['will', 'it', 'be', 'raining', 'tomorrow'],
#   ['will',
#    'there',
#    'be',
#    'sunset',
#    'at',
#    'five',
#    'hundred',
#    'and',
#    'thirty',
#    'pm',
#    'tomorrow'],
#   ['is', 'there', 'any', 'chances', 'of', 'rain', 'this', 'week'],
#   ['show', 'latest', 'news'],
#   ['what', 'is', 'trending'],
#   ['what', 'is', 'new', 'news', 'for', 'today'],
#   ['what', 'is', 'the', 'time', 'in', 'the', 'pacific', 'timezone'],
#   ['what', 'is', 'the', 'time', 'in', 'the', 'eastern', 'timezone'],
#   ['what', 'is', 'the', 'time', 'in', 'alaska'],
#   ['what', 'is', 'the', 'current', 'weather'],
#   ['how', 'warm', 'is', 'it', 'now'],
#   ['please',
#    'turn',
#    'on',
#    'the',
#    'music',
#    'i',
#    'want',
#    'to',
#    'hear',
#    'my',
#    'favorites',
#    'songs'],
#   ['can',
#    'i',
#    'hear',
#    'the',
#    'fifty',
#    'hits',
#    'that',
#    'you',
#    'can',
#    'hear',
#    'on',
#    'radios',
#    'now'],
#   ['please', 'turn', 'on', 'classic', 'music', 'for', 'the', 'dinner', 'now'],
#   ['please',
#    'i',
#    'want',
#    'to',
#    'hear',
#    'we',
#    'will',
#    'rock',
#    'you',
#    'from',
#    'queen'],
#   ['can', 'you', 'turn', 'on', 'the', 'hit', 'song', 'of', 'lady', 'gaga'],
#   ['i',
#    'want',
#    'to',
#    'hear',
#    'my',
#    'favorite',
#    'song',
#    'from',
#    'iron',
#    'maiden'],
#   ['turn', 'up', 'sound'],
#   ['turn', 'down', 'volume'],
#   ['volume', 'louder', 'please'],
#   ['start', 'alarm'],
#   ['set', 'alarm', 'to', 'begin'],
#   ['change', 'alarm', 'to', 'start', 'at'],
#   ['what', 'will', 'the', 'weather', 'be', 'like', 'a', 'week', 'from', 'now'],
#   ['on', 'tuesday', 'what', 'is', 'the', 'weather', 'supposed', 'to', 'be'],
#   ['what', 'is', 'the', 'weekend', 'weather', 'forecast'],
#   ['set', 'mute', 'for', 'twenty', 'mins'],
#   ['unmute', 'after'],
#   ['bring', 'back', 'talking', 'after'],
#   ['i',
#    'want',
#    'to',
#    'wake',
#    'up',
#    'at',
#    'six',
#    'hundred',
#    'am',
#    'tomorrow',
#    'please'],
#   ['please',
#    'set',
#    'the',
#    'alarm',
#    'for',
#    'next',
#    'morning',
#    'to',
#    'seven',
#    'am'],
#   ['please',
#    'ring',
#    'the',
#    'wake',
#    'up',
#    'alarm',
#    'at',
#    'eight',
#    'am',
#    'next',
#    'saturday'],
#   ['play', 'playlist', 'number', 'seven'],
#   ['start', 'playlist'],
#   ['play', 'songs', 'from', 'my', 'playlist'],
#   ['what', 'day', 'of', 'the', 'week', 'is', 'thanksgiving'],
#   ['what', 'is', 'the', 'last', 'day', 'of', 'the', 'month'],
#   ['what', 'day', 'of', 'the', 'month', 'is', 'fat', 'tuesday'],
#   ['what', 'time', 'is', 'it', 'eastern'],
#   ['what', 'is', 'the', 'time', 'central'],
#   ['what', 'is', 'the', 'current', 'mountain', 'time'],
#   ['what', 'is', 'latest', 'controversy', 'on', 'donald', 'trump'],
#   ['tell',
#    'me',
#    'about',
#    'current',
#    'status',
#    'of',
#    'sunderland',
#    'vs',
#    'liverpool',
#    'match',
#    'how',
#    'is',
#    'the',
#    'performance',
#    'of',
#    'liverpool',
#    'in',
#    'this',
#    'match'],
#   ['tell',
#    'me',
#    'that',
#    'how',
#    'demonetization',
#    'policy',
#    'is',
#    'affecting',
#    'india',
#    'tell',
#    'me',
#    'all',
#    'the',
#    'positive',
#    'and',
#    'negative',
#    'outcomes',
#    'of',
#    'demonetization'],
#   ['please', 'play', 'the', 'radio', 'gaga', 'song'],
#   ['please',
#    'let',
#    'me',
#    'hear',
#    'six',
#    'hundred',
#    'and',
#    'sixty',
#    'six',
#    'the',
#    'number',
#    'of',
#    'the',
#    'beast'],
#   ['play',
#    'the',
#    'last',
#    'hit',
#    'song',
#    'of',
#    'metallica',
#    'last',
#    'album',
#    'please'],
#   ['tell',
#    'me',
#    'about',
#    'latest',
#    'controversial',
#    'news',
#    'of',
#    'kim',
#    'kardashian'],
#   ['did',
#    'the',
#    'bitcoin',
#    'go',
#    'past',
#    'ten',
#    'mark',
#    'yesterday',
#    'what',
#    'is',
#    'position',
#    'of',
#    'bitcoin',
#    'as',
#    'of',
#    'now'],
#   ['tell',
#    'me',
#    'about',
#    'first',
#    'week',
#    'collection',
#    'of',
#    'movie',
#    'hidden',
#    'figures',
#    'and',
#    'also',
#    'tell',
#    'about',
#    'the',
#    'reviews',
#    'and',
#    'rating',
#    'of',
#    'the',
#    'movie'],
#   ['let',
#    'me',
#    'know',
#    'when',
#    'there',
#    'is',
#    'news',
#    'on',
#    'the',
#    'dakota',
#    'pipeline'],
#   ['set', 'notification', 'for', 'news', 'about', 'the', 'dakota', 'pipeline'],
#   ['notify',
#    'me',
#    'when',
#    "there's",
#    'news',
#    'on',
#    'the',
#    'dakota',
#    'pipeline'],
#   ['start', 'vaccum'],
#   ['begin', 'vaccum'],
#   ['please', 'start', 'vacuum', 'cleaner'],
#   ['what', 'is', 'a', 'funny', 'joke', 'about', 'car'],
#   ['tell', 'me', 'a', 'joke', 'about', 'a', 'man'],
#   ['can', 'you', 'find', 'an', 'animal', 'joke', 'for', 'me'],
#   ['rate', 'this', 'song', 'to', 'the', 'maximum'],
#   ['remind', 'me', 'to', 'play', 'this', 'song', 'tonight'],
#   ['find',
#    'lyrics',
#    'of',
#    'this',
#    'song',
#    'and',
#    'save',
#    'it',
#    'it',
#    'is',
#    'very',
#    'nice',
#    'song'],
#   ['please', 'play', 'me', 'a', 'song', 'from', 'my', 'fevorate', 'list'],
#   ['play', 'me', 'a', 'song'],
#   ['play', 'me', 'a', 'song', 'of', 'adele'],
#   ['can', 'you', 'turn', 'on', 'the', 'vacuum', 'cleaner'],
#   ['i', 'need', 'you', 'to', 'turn', 'on', 'the', 'vacuum', 'cleaner'],
#   ['what', 'will', 'be', 'the', 'highest', 'temperature', 'this', 'week'],
#   ['what', 'chances', 'are', 'of', 'snowfall', 'this', 'month'],
#   ['slightly', 'raise', 'the', 'light'],
#   ['increase', 'the', 'light', 'a', 'little'],
#   ['make', 'the', 'light', 'more', 'visible'],
#   ['can', 'you', 'tell', 'me', 'what', 'alarms', 'i', 'have', 'set'],
#   ['do', 'i', 'have', 'any', 'alarms', 'set', 'for', 'today'],
#   ['i',
#    'need',
#    'to',
#    'set',
#    'an',
#    'alarm',
#    'how',
#    'many',
#    'do',
#    'i',
#    'have',
#    'set'],
#   ['turn', 'off', 'the', 'room', 'lights'],
#   ['turn', 'off', 'room', 'lights'],
#   ['control', 'lights', 'turn', 'off', 'room', 'lights'],
#   ['can', 'locate', 'some', 'gospel', 'music'],
#   ['can', 'you', 'locate', 'some', 'gospel', 'music', 'for', 'me'],
#   ['i', 'want', 'to', 'listen', 'to', 'some', 'gospel', 'music'],
#   ['how', 'is', 'the', 'current', 'weather', 'in', 'california'],
#   ['how', 'is', 'the', 'current', 'weather', 'in', 'washington', 'dc'],
#   ['what', 'is', 'status', 'of', 'current', 'weather'],
#   ['what', 'is', 'time', 'now', 'in', 'california'],
#   ['time', 'now', 'in', 'new', 'york'],
#   ['current', 'time', 'in', 'japan'],
#   ['please',
#    'can',
#    'i',
#    'know',
#    'what',
#    'time',
#    'will',
#    'it',
#    'be',
#    'at',
#    'six',
#    'pm',
#    'here',
#    'in',
#    'australia'],
#   ['can',
#    'you',
#    'tell',
#    'how',
#    'many',
#    'hours',
#    'of',
#    'difference',
#    'are',
#    'between',
#    'boston',
#    'and',
#    'los',
#    'angeles'],
#   ['please',
#    'convert',
#    'the',
#    'time',
#    'of',
#    'here',
#    'at',
#    'nine',
#    'pm',
#    'to',
#    'brasil',
#    'timezone'],
#   ['turn', 'the', 'lights', 'down'],
#   ['can', 'you', 'lower', 'the', 'lights'],
#   ['i', 'need', 'to', 'turn', 'the', 'lights', 'down'],
#   ['lower', 'the', 'brightness'],
#   ['reduce', 'brightness'],
#   ['i', 'want', 'two', 'burgers', 'and', 'one', 'coke', 'order', 'it', 'fast'],
#   ['order', 'two', 'hamburgers', 'for', 'me'],
#   ['place', 'order', 'of', 'one', 'pizza'],
#   ['can', 'you', 'tell', 'me', 'what', 'date', 'it', 'is'],
#   ['can', 'you', 'tell', 'me', 'what', 'time', 'it', 'is'],
#   ['can', 'you', 'tell', 'me', 'what', 'month', 'it', 'is'],
#   ['can', 'you', 'tell', 'me', 'what', 'time', 'is', 'it'],
#   ['what', 'time', 'is', 'it', 'now'],
#   ['display', 'current', 'time'],
#   ['give', 'me', 'date', 'and', 'time'],
#   ['set', 'timezone'],
#   ['please',
#    'turn',
#    'off',
#    'the',
#    'plug',
#    'socket',
#    'of',
#    'my',
#    'phone',
#    'when',
#    "it'll",
#    'be',
#    'charged'],
#   ['turn', 'on', 'the', 'tv', 'socket', 'when', 'i', 'arrive', 'home'],
#   ['i',
#    'want',
#    'you',
#    'to',
#    'turn',
#    'off',
#    'the',
#    'plug',
#    'socket',
#    'before',
#    'the',
#    'cellphone',
#    'is',
#    'charged'],
#   ['keep', 'me', 'informed', 'about', 'bitcoin', 'price'],
#   ['keep', 'me', 'uted', 'on', 'stock', 'market', 'prices'],
#   ['follow', 'news', 'about', 'hilary', 'email', 'issue', 'in', 'future'],
#   ['can', 'you', 'play', 'my', 'last', 'song'],
#   ['play', 'the', 'song', 'by', 'michael', 'jackson'],
#   ['play', 'the', 'song', 'from', 'last', 'night', 'at', 'six', 'pm'],
#   ['what', 'is', 'the', 'time', 'now', 'in', 'new', 'york'],
#   ['give', 'me', 'the', 'time', 'in', 'washington'],
#   ['give', 'me', 'the', 'time', 'at', 'washington', 'right', 'now'],
#   ['lower', 'the', 'volume'],
#   ['it', 'is', 'too', 'loud', 'decrease', 'the', 'volume'],
#   ['i', "can't", 'hear', 'just', 'increase', 'the', 'volume'],
#   ['who', 'is', 'singing', 'that', 'song', 'on', 'now'],
#   ['what',
#    'is',
#    'the',
#    'name',
#    'of',
#    'that',
#    'song',
#    'that',
#    'just',
#    'went',
#    'off'],
#   ['i',
#    'just',
#    'ordered',
#    'food',
#    'call',
#    'and',
#    'see',
#    'it',
#    'has',
#    'been',
#    'delivered'],
#   ['check', 'on', 'the', 'delivery', 'of', 'my', 'current', 'order'],
#   ['call',
#    'the',
#    'restaurant',
#    'to',
#    'see',
#    'if',
#    'the',
#    'delivery',
#    'is',
#    'on',
#    'the',
#    'way'],
#   ['please', 'brighten', 'the', 'room'],
#   ['can', 'you', 'bright', 'the', 'lights', 'please'],
#   ['i', 'want', 'to', 'bright', 'the', 'room', 'more'],
#   ['what', 'alarms', 'are', 'set', 'for', 'today'],
#   ['today', 'how', 'many', 'alarms', 'do', 'i', 'have', 'set'],
#   ['what', 'happening', 'in', 'va'],
#   ["what's", 'going', 'on', 'in', 'congress'],
#   ['what', 'is', 'the', 'weather', 'report'],
#   ['show', 'weather', 'info'],
#   ['check', 'weather'],
#   ['hi', 'can', 'you', 'please', 'turn', 'lower', 'the', 'lights'],
#   ['i', 'want', 'the', 'lights', 'less', 'brighter'],
#   ['please', 'lights', 'less', 'brighter'],
#   ['tell', 'me', 'something', 'funny'],
#   ['i', 'want', 'to', 'hear', 'radio', 'head', 'please'],
#   ['play', 'madonna', 'now'],
#   ['i', 'want', 'to', 'hear', 'chopin', 'now'],
#   ['who', 'is', 'leading', 'the', 'formula', 'one', 'race', 'right', 'now'],
#   ['what',
#    'is',
#    'the',
#    'scorecard',
#    'of',
#    'the',
#    'india',
#    'versus',
#    'australia',
#    'hockey',
#    'game'],
#   ['get', 'me', 'the', 'utes', 'of', 'the', 'election', 'polling'],
#   ['prepare', 'coffee'],
#   ['read', 'the', 'headlines', 'from', 'new', 'york', 'times'],
#   ['i', 'want', 'to', 'hear', 'the', 'last', 'news', 'form', 'cnn'],
#   ['can',
#    'you',
#    'show',
#    'me',
#    'the',
#    'last',
#    'breaking',
#    'news',
#    'form',
#    'wsj'],
#   ['give', 'me', 'ute', 'on', 'news'],
#   ['what', 'is', 'happening', 'now', 'in', 'world'],
#   ['give', 'me', 'a', 'news', 'paper'],
#   ['i', 'want', 'to', 'know', 'the', 'news', 'form', 'miami', 'herald'],
#   ['please', 'read', 'me', 'the', 'last', 'news', 'from', 'boston', 'tribute'],
#   ['can', 'i', 'know', 'the', 'breaking', 'news', 'from', 'cnn'],
#   ['hi'],
#   ['hello'],
#   ['create', 'an', 'alarm', 'at', 'four', "o'clock", 'tomorrow', 'morning'],
#   ['make', 'an', 'alarm', 'to', 'wake', 'me', 'up', 'after', 'five', 'hours'],
#   ['schedule',
#    'an',
#    'alarm',
#    'to',
#    'wake',
#    'me',
#    'up',
#    'after',
#    'three',
#    'hours'],
#   ['give', 'weather', 'stat', 'for', 'the', 'week'],
#   ['display', 'weather', 'for', 'the', 'week'],
#   ['summarise', "week's", 'weather', 'details'],
#   ['play', 'the', 'latest', 'song', 'adele'],
#   ['i', 'want', 'to', 'hear', 'the', 'songs', 'of', 'adele'],
#   ['play', 'enrique', 'iglesias', 'song', 'after', 'this', 'one'],
#   ['play',
#    'the',
#    'latest',
#    'songs',
#    'by',
#    'senelena',
#    'gomez',
#    'after',
#    'this',
#    'o'],
#   ['turn', 'the', 'lights', 'off'],
#   ['turn', 'out', 'the', 'lights'],
#   ['save', 'my', 'music', 'preferences'],
#   ['save', 'my', 'music', 'choices'],
#   ['play', 'music', 'i', 'have', 'liked'],
#   ['could', 'you', 'please', 'lower', 'your', 'volume'],
#   ['could', 'you', 'please', 'yell', 'the', 'answer', 'out', 'to', 'me'],
#   ['could', 'you', 'please', 'lower', 'the', 'tone'],
#   ['how', 'cold', 'is', 'it', 'outside', 'today'],
#   ['what', 'is', 'the', 'temperature', 'today'],
#   ['how', 'humid', 'is', 'the', 'environment', 'today'],
#   ['play', 'songs', 'from', 'the', 'r.', 'n.', 'b.', 'and', 'soul', 'genre'],
#   ['play', 'all', 'the', 'latest', 'pop', 'songs'],
#   ['play', 'all', 'the', 'list', 'of', 'country', 'songs'],
#   ['play', '<unk>', 'playlist', 'next'],
#   ['i', 'want', 'to', 'hear', '<unk>', 'playlist', 'next'],
#   ['listen', 'to', '<unk>', 'playlist', 'next'],
#   ["what's", 'trending'],
#   ['get', 'me', 'top', 'headlines'],
#   ['play', 'me', 'song', 'my', 'travel', 'playlist'],
#   ['play', 'song', 'from', 'my', 'trance', 'list'],
#   ['please', 'decrease', 'the', 'volume', 'of', 'this', 'song'],
#   ['increase',
#    'the',
#    'volume',
#    'so',
#    'that',
#    'i',
#    'can',
#    'hear',
#    'it',
#    'in',
#    'other',
#    'room'],
#   ['decrease', 'the', 'volume', 'to', 'ten', 'percent'],
#   ["don't", 'talk', 'until', 'i', 'ask', 'you', 'to'],
#   ['mute', 'yourself', 'until', 'i', 'say', 'otherwise'],
#   ["don't", 'speak', 'for', 'a', 'while'],
#   ['change', 'the', 'time', 'zone', 'from', 'washington', 'to', 'new', 'york'],
#   ['change', 'this', 'time', 'zone', 'to', 'wasington'],
#   ['change', 'the', 'time', 'in', 'this', 'location', 'to', 'ist'],
#   ['can', 'u', 'turn', 'off', 'wemo', 'plug', 'socket'],
#   ['turn',
#    'on',
#    'the',
#    'wemo',
#    'plug',
#    'socket',
#    'to',
#    'connect',
#    'my',
#    'charger',
#    'to',
#    'it'],
#   ['turn',
#    'on',
#    'the',
#    'wemo',
#    'plug',
#    'socket',
#    'to',
#    'plug',
#    'in',
#    'my',
#    'dongle'],
#   ['find', 'me', 'the', 'song', 'currently', 'palying'],
#   ['what', 'is', 'name', 'of', 'the', 'song', 'currently', 'playing'],
#   ['i', 'want', 'to', 'know', 'about', 'this', 'song'],
#   ['please', 'make', 'a', 'coffee'],
#   ['can', 'you', 'bring', 'me', 'a', 'nice', 'coffee'],
#   ['i', 'want', 'to', 'drink', 'the', 'coffee', 'that', 'you', 'made'],
#   ['what', 'does', 'the', 'weather', 'look', 'like', 'this', 'week'],
#   ['what',
#    'is',
#    'the',
#    'weather',
#    'supposed',
#    'to',
#    'be',
#    'like',
#    'this',
#    'week'],
#   ['what', 'is', 'the', 'weather', 'forecast', 'for', 'this', 'week'],
#   ['could',
#    'you',
#    'please',
#    'give',
#    'me',
#    'up',
#    'to',
#    'date',
#    'news',
#    'headlines',
#    'from',
#    'my',
#    'newest',
#    'provider'],
#   ['could',
#    'you',
#    'please',
#    'search',
#    'my',
#    'new',
#    'news',
#    'provider',
#    'for',
#    'the',
#    'latest',
#    'news'],
#   ['could',
#    'you',
#    'please',
#    'find',
#    'me',
#    'the',
#    'latest',
#    'news',
#    'from',
#    'a',
#    'source',
#    'that',
#    'i',
#    'do',
#    'not',
#    'usually',
#    'go',
#    'to'],
#   ['tell', 'me', 'about', 'the', 'latest', 'political', 'news'],
#   ['tell', 'me', 'about', 'the', 'latest', 'sports', 'news'],
#   ["what's", 'going', 'around', 'in', 'the', 'world', 'these', 'days'],
#   ['give', 'me', 'the', 'news', 'ute', 'from', 'bbc'],
#   ['what', 'are', 'the', 'news', 'ute', 'on', 'bbc'],
#   ['show', 'me', 'the', 'latest', 'news', 'on', 'bbc'],
#   ['notify', 'me', 'when', 'trump', 'is', 'in', 'the', 'news'],
#   ['tell', 'me', 'if', 'an', 'earthquake', 'happens', 'in', 'the', 'world'],
#   ['alert',
#    'me',
#    'when',
#    'the',
#    'outside',
#    'temperature',
#    'reaches',
#    'sixty',
#    'eight',
#    'degrees'],
#   ['play', 'boogie', 'in', 'your', 'butt', 'by', 'eddie', 'murphy'],
#   ['i', 'want', 'to', 'hear', 'snow', 'by', 'red', 'hot', 'chili', 'peppers'],
#   ['listen', 'to', 'girl', 'from', 'impanema', 'by', 'frank', 'sinatra'],
#   ['play', 'slow', 'down', 'the', 'song'],
#   ['play', 'bilando'],
#   ['play', 'let', 'me', 'love', 'you', 'by', 'ariana', 'grande'],
#   ['play', "'love", 'songs'],
#   ['stream', 'all', 'songs', 'from', "'rock"],
#   ['add', 'shape', 'of', 'you', 'to', 'the', 'current', 'queue'],
#   ['hey', 'how', 'are', 'you'],
#   ['how', 'is', 'the', 'weather', 'today'],
#   ['what', 'is', 'the', 'temperature', 'right', 'now'],
#   ['how', 'was', 'the', 'weather', 'this', 'week'],
#   ['mild', 'or', 'heavy', 'weather'],
#   ['show', 'me', 'the', 'highest', 'weather', 'this', 'week'],
#   ['is', 'summer', 'going', 'on'],
#   ['what', 'are', 'the', 'chances', 'of', 'hail', 'this', 'week'],
#   ['confirm', 'alarm', 'for', 'tomorrow', 'morning'],
#   ['what', 'time', 'is', 'the', 'alarm', 'set', 'for', 'tomorrow'],
#   ['confirm', 'my', 'alarm', 'settings'],
#   ['could',
#    'you',
#    'please',
#    'recommend',
#    'a',
#    'mexican',
#    'restaurant',
#    'for',
#    'take',
#    'out'],
#   ['which', 'restaurants', 'offer', 'take', 'out', 'food'],
#   ['can', 'i', 'order', 'take', 'out', 'food', 'at', 'this', 'time'],
#   ['i',
#    'want',
#    'to',
#    'know',
#    'the',
#    'latest',
#    'local',
#    'news',
#    'of',
#    'the',
#    'city'],
#   ['get',
#    'me',
#    'the',
#    'latest',
#    'sports',
#    'utes',
#    'and',
#    'news',
#    'of',
#    'the',
#    'world'],
#   ['whats',
#    'the',
#    'latest',
#    'from',
#    'the',
#    'business',
#    'and',
#    'economics',
#    'sector'],
#   ['mute', 'sound', 'on', 'speakers', 'please'],
#   ['hey', 'siri', 'mute', 'the', 'speakers'],
#   ['lower', 'all', 'volume', 'on', 'speakers', 'please'],
#   ['make', 'coffee', 'now'],
#   ['make', 'coffee', 'at', 'eight', 'am'],
#   ['brew', 'coffee', 'at', 'noon'],
#   ['what', 'day', 'of', 'the', 'month', 'is', 'it'],
#   ['play', 'new', 'gaga', 'playlist'],
#   ['start', 'new', 'lady', 'gaga', 'playlist'],
#   ['play', 'lady', 'gaga', 'starting', 'with', 'poker', 'face'],
#   ['open', 'the', 'new', 'york', 'times', 'app'],
#   ['open',
#    'my',
#    'morning',
#    'briefing',
#    'email',
#    'from',
#    'the',
#    'new',
#    'york',
#    'times'],
#   ['open', 'the', 'r', 'news', 'subreddit', 'on', 'reddit'],
#   ['play', 'some', 'music'],
#   ['go',
#    'to',
#    'pandora',
#    'find',
#    'twenty',
#    'one',
#    'pilots',
#    'radio',
#    'play',
#    'please'],
#   ['google', 'music', 'find', 'me', 'some', 'enya', 'to', 'listen', 'to'],
#   ['increase', 'the', 'volume'],
#   ['put', 'the', 'playlist', 'on', 'shuffle'],
#   ['stop', 'repeating', 'this', 'song'],
#   ['what', 'is', 'the', 'weather', 'where', 'i', 'am', 'at', 'today'],
#   ['show', 'me', 'the', 'seven', 'day', 'forcast', 'for', 'home', 'please'],
#   ['what',
#    'is',
#    'the',
#    'current',
#    'temperature',
#    'and',
#    'humidity',
#    'outside'],
#   ['play', 'bob', 'dylan', 'playlist'],
#   ['play', 'newest', 'bob', 'dylan', 'playlist'],
#   ['play', 'new', 'bob', 'dylan', 'album'],
#   ['hey',
#    'its',
#    'too',
#    'hot',
#    'outside',
#    'what',
#    'is',
#    'the',
#    'temperature',
#    'this',
#    'afternoon'],
#   ['hey',
#    'what',
#    'will',
#    'be',
#    'the',
#    'predicted',
#    'weather',
#    'for',
#    'tomorrow'],
#   ['is', 'it', 'going', 'to', 'snow', 'this', 'weekend', 'here'],
#   ['tell', 'me', 'the', 'latest', 'news', 'from', 'bbc', 'sports'],
#   ['what', 'is', 'latest', 'gossip', 'of', 'hwood', 'going', 'on'],
#   ['what',
#    'are',
#    'the',
#    'bbc',
#    'poll',
#    'predictions',
#    'for',
#    'the',
#    'upcoming',
#    'us',
#    'elections'],
#   ['remove', 'wake', 'up', 'calls', 'for', 'this', 'week'],
#   ['cancel', 'wake', 'up', 'calls', 'for', 'this', 'week'],
#   ['stop', 'wake', 'up', 'calls', 'for', 'this', 'week'],
#   ['order', 'takeout', 'pizza', 'from', "domino's", 'for', 'seven', 'pm'],
#   ['place', 'order', 'to', 'pizza', 'takeout', 'for', 'seven', 'pm'],
#   ['schedule', 'pizza', 'takeout', 'for', 'seven', 'pm'],
#   ['start', 'the', 'robot', 'roomba'],
#   ['turn', 'the', 'robot', 'vacuum', 'cleaner', 'on'],
#   ['what', 'alarms', 'are', 'set', 'right', 'now'],
#   ['what', 'alarms', 'will', 'wake', 'me', 'up', 'tomorrow'],
#   ['are', 'there', 'any', 'alarms', 'set', 'right', 'now'],
#   ['i', 'would', 'like', 'a', 'joke'],
#   ['give', 'me', 'a', 'joke'],
#   ['a', 'joke', 'please'],
#   ['brighten', 'lights'],
#   ['turn', 'up', 'lights'],
#   ['lights', 'brighter'],
#   ['play', 'r.', 'n.', 'b.', 'music'],
#   ['play', 'r.', 'n.', 'b.'],
#   ['r.', 'n.', 'b.', 'music'],
#   ['dim', 'lights'],
#   ['lights', 'dim'],
#   ['weather', 'forcast'],
#   ['forcast'],
#   ['weather', 'today'],
#   ['my', 'set', 'alarms'],
#   ['alarm', 'settings'],
#   ['my', 'alarms'],
#   ['robot', 'vacuum', 'the', 'living', 'room', 'now'],
#   ['robot', 'do', 'the', 'whole', 'house', 'now'],
#   ['robot', 'vacuum', 'the', 'hallway', 'now'],
#   ['turn', 'off', 'wemo'],
#   ['turn', 'off', 'smart', 'socket'],
#   ['wemo', 'plug', 'socket', 'off'],
#   ['save', 'opinion'],
#   ['opinion', 'save'],
#   ['add', 'opinion'],
#   ['turn', 'off', 'light', 'in', 'bedroom'],
#   ['shutoff', 'light', 'in', 'the', 'kitchen'],
#   ['switch', 'the', 'light', 'off', 'in', 'bedroom'],
#   ['play', 'jars', 'of', "clay's", 'if', 'i', 'left', 'the', 'zoo'],
#   ['play', 'crystal', "lewis's", 'beauty', 'of', 'the', 'cross', 'for', 'me'],
#   ['play', 'kari', 'jobe', 'for', 'me'],
#   ['order', 'food'],
#   ['food', 'order', 'from', 'grubhub'],
#   ['grubhub', 'order'],
#   ['what', 'time', 'is', 'it', 'in', 'miami', 'florida'],
#   ['what', 'time', 'is', 'it', 'in', 'cleveland', 'ohio'],
#   ['what', 'time', 'is', 'it', 'in', 'honolulu'],
#   ['news', 'nineteen'],
#   ['news', 'from', 'state', 'paper'],
#   ['news', 'articles'],
#   ['set', 'alarm', 'for', 'eight', 'am'],
#   ['alarm', 'set', 'eight', 'am'],
#   ['tell', 'me', 'what', 'time', 'it', 'is', 'right', 'now'],
#   ['give', 'me', 'the', 'current', 'time'],
#   ['what', 'time', 'are', 'we', 'looking', 'at', 'right', 'now'],
#   ['play', 'some', 'tunes', 'for', 'me'],
#   ['play', 'some', 'good', 'background', 'musc'],
#   ['play', 'some', 'calming', 'music', 'for', 'me'],
#   ['play', 'some', 'christian', 'music'],
#   ['i', 'want', 'to', 'hear', 'some', 'tunes'],
#   ['play', 'music', 'now'],
#   ['turn', 'off', 'the', 'alarm', 'for', 'tomorrow', 'morning'],
#   ['turn', 'off', 'the', 'six', 'am', 'alarm', 'for', 'wednesday'],
#   ['turn', 'off', 'any', 'morning', 'alarms', 'after', 'friday'],
#   ['make', 'the', 'house', 'lights', 'amber', 'at', 'six', 'pm'],
#   ['turn', 'the', 'lights', 'blue', 'at', 'three', 'pm'],
#   ['give', 'me', 'some', 'lavender', 'toned', 'light'],
#   ['let',
#    'me',
#    'know',
#    'any',
#    'utes',
#    'about',
#    'new',
#    'trump',
#    'cabinet',
#    'appointments'],
#   ['notify', 'me', 'about', 'any', 'utes', 'on', 'vaccine', 'laws'],
#   ['let',
#    'me',
#    'know',
#    'when',
#    'the',
#    'next',
#    'cold',
#    'front',
#    'is',
#    'expected'],
#   ['make', 'a', 'jars', 'of', 'clay', 'playlist', 'for', 'me'],
#   ['find', 'new', 'music', 'from', 'jars', 'of', 'clay', 'for', 'me'],
#   ['make',
#    'a',
#    'playlist',
#    'of',
#    'music',
#    'from',
#    'artists',
#    'on',
#    'the',
#    'exodus',
#    'cd'],
#   ['what', 'will', 'the', 'weather', 'be', 'for', 'the', 'next', 'week'],
#   ['what', 'will', 'the', 'temperatures', 'be', 'for', 'the', 'next', 'week'],
#   ['look', 'up', 'next', 'weeks', 'weather', 'for', 'me', 'please'],
#   ['can', 'you', 'turn', 'on', 'the', 'vacuum'],
#   ['will', 'you', 'have', 'the', 'vacuum', 'start', 'cleaning'],
#   ['please', 'set', 'the', 'vacuum', 'to', 'start', 'going', 'now'],
#   ['what', 'time', 'is', 'it', 'in', 'new', 'york'],
#   ['what', 'time', 'is', 'it', 'right', 'now', 'in', 'new', 'york'],
#   ['please', 'tell', 'me', 'the', 'current', 'time', 'in', 'new', 'york'],
#   ['play', 'my', 'favorite', 'station'],
#   ['play', 'my', 'favorite', 'pandora', 'station'],
#   ['play', 'pandora'],
#   ['please', 'turn', 'lights', 'off'],
#   ['turn', 'the', 'lights', 'off', 'to', 'my', 'room'],
#   ['please', 'tell', 'me', 'what', 'time', 'it', 'is'],
#   ['remove', 'my', 'morning', 'alarm'],
#   ['please', 'delete', 'my', 'morning', 'alarm'],
#   ['please', 'remove', 'my', 'alarm'],
#   ['play', 'music', 'from', 'my', 'favorite', 'artist'],
#   ['play', 'music', 'from', 'my', 'favorite', 'pandora', 'artist', 'station'],
#   ['play', 'music', 'from', 'a', 'given', 'artist'],
#   ['dim', 'the', 'lights', 'a', 'bit'],
#   ['please', 'lower', 'the', 'lights', 'a', 'little', 'bit'],
#   ['lower', 'the', 'lights', 'a', 'little', 'more'],
#   ['who', 'sings', 'this', 'song'],
#   ['what', 'is', 'the', 'name', 'of', 'this', 'song'],
#   ['name', 'the', 'singer'],
#   ['repeat', 'this', 'song'],
#   ['i', 'like', 'this', 'song', 'plesse', 'save'],
#   ['please', 'save', 'this', 'song'],
#   ['make', 'this', 'my', 'favorite'],
#   ['change', 'the', 'volume', 'of', 'the', 'speakers'],
#   ['can', 'you', 'turn', 'on', 'pandora'],
#   ['open', 'up', 'and', 'play', 'music', 'from', 'my', 'jogging', 'playlist'],
#   ['play', 'a', 'song', 'by', 'paramore'],
#   ['phones'],
#   ['personal', 'data', 'assistants'],
#   ['set', 'my', 'alarm', 'for', 'seven', 'am'],
#   ['turn', 'my', 'morning', 'alarm', 'on'],
#   ['set', 'my', 'alarm', 'please'],
#   ['what', 'is', 'the', 'time', 'in', 'london', 'right', 'now'],
#   ['if',
#    "it's",
#    'eight',
#    'pm',
#    'on',
#    'the',
#    'east',
#    'coast',
#    'what',
#    'time',
#    'is',
#    'it',
#    'in',
#    'sacramento',
#    'california'],
#   ['what',
#    'is',
#    'the',
#    'time',
#    'difference',
#    'between',
#    'here',
#    'and',
#    'japan'],
#   ['encourage', 'the', 'students'],
#   ['decentralized', 'design'],
#   ['following', 'scenario', 'to', 'answer', 'questions'],
#   ['i', 'like', 'the', 'background', 'song'],
#   ['that', 'song', 'in', 'the', 'background', 'is', 'annoying'],
#   ['what', 'is', 'the', 'weather', 'like', 'in', 'new', 'york'],
#   ['whats', 'the', 'weather', 'like', 'right', 'now', 'in', 'new', 'york'],
#   ['is', 'the', 'weather', 'bad', 'in', 'new', 'york', 'right', 'now'],
#   ['will', 'you', 'please', 'mute', 'my', 'speakers'],
#   ['sound', 'off'],
#   ['set', 'the', 'alarm', 'for', 'five', "o'clock", 'in', 'the', 'morning'],
#   ['set',
#    'my',
#    'alarm',
#    'for',
#    'six',
#    'thirty',
#    'in',
#    'the',
#    'morning',
#    'tomorrow'],
#   ['i', 'want', 'the', 'alarm', 'set', 'for', 'si', '<unk>'],
#   ['security',
#    'devices',
#    'to',
#    'robotic',
#    'vacuum',
#    'cleaners',
#    'to',
#    'internet',
#    'enabled',
#    'refrigerators'],
#   ['asking', 'for', 'this', 'technology'],
#   ...],
#  array([34, 34, 34, ..., 27, 27, 27]))

# %%
# Out:
# 0            wake me up at five am this week
# 1            wake me up at nine am on friday
# 2        set an alarm for two hours from now
# 3                                      quiet
# 4                                       stop
#                         ...
# 25711                                    NaN
# 25712                                    NaN
# 25713                                    NaN
# 25714                                    NaN
# 25715                                    NaN
# Name: answer_normalised, Length: 25716, dtype: object
